# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from torchvision import transforms, models
import random

# %%
root = '/home/data/7/car/'

# %%
os.listdir(root)
# Out:
# ['2ae214c760374e82a8d9c38b85579964~1.jpg',
#  '1ffc31d324b34006abb14515fff8cabb~1.jpg',
#  '2b2b6ac2f028417fa822e849981bd97c~1.jpg']

# %%
img = Image.open(root + '1ffc31d324b34006abb14515fff8cabb~1.jpg')
plt.imshow(img)

# %%
img_np = np.array(img)
img_np.shape
# Out:
# (144, 256, 3)

# %%
size = 112

random_pad = tuple(random.choices(list(range(0, 10)), k=4))

print(random_pad)

trans = transforms.Compose([
            transforms.Resize((size, size)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
        ])
# Out:
# (1, 8, 4, 6)

# %%
img = transforms.Pad(padding=random_pad, fill=(255, 255, 255))(img)
plt.imshow(img)

# %%
img = trans(img).numpy().transpose((1, 2, 0))

# %%
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
